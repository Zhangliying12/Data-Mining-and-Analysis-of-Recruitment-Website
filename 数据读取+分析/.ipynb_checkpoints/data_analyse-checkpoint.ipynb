# %%
import pandas as pd
import MySQLdb

# 职位类型在数据库中的表名和中文对应键值对
position_dict = {
    'ai':'人工智能',
    'backend':"后端开发",
    'DBA':'数据库管理员',
    'enterprise_software':'企业软件开发',
    'frontend':'前端',
    'hardware_development':'硬件开发',
    'high_position':'高端职位',
    'mobile_development':'移动开发',
    'operation_maintenance':'运维',
    'project_management':'项目管理',
    'software_test':'软件测试'
}

attr = [
    'position',
    'salary_min',
    'salary_max',
    'experience',
    'degree',
    'work_place',
    'company_name',
    'company_type',
    'company_finance',
    'company_scale',
    'bonus',
    'url'
]

#连接数据库
conn = MySQLdb.connect(host="localhost",user="root",passwd="root",db="job_info",charset="utf8")

def read_from_db(table_name):
    sql = "select * from " + table_name
    df = pd.read_sql(sql,conn)
    return df

# 读取每一类型的职位的数据
df_ai = read_from_db('ai')
df_backend = read_from_db('backend')
df_DBA = read_from_db('DBA')
df_enterprise_software = read_from_db('enterprise_software')
df_frontend = read_from_db('frontend')
df_hardware_development = read_from_db('hardware_development')
df_high_position = read_from_db('high_position')
df_mobile_development = read_from_db('mobile_development')
df_operation_maintenance = read_from_db('operation_maintenance')
df_project_management = read_from_db('project_management')
df_software_test = read_from_db('software_test')

# 合并所有数据库中的数据
df_all = pd.DataFrame()
for k in position_dict.keys():
    df = read_from_db(k)
    df_all = pd.concat([df_all,df])
conn.close()

# %% [markdown]
# # 数据清洗：

# %%
"""
数据清洗过程：
1. 去掉重复项
2. 去掉含有空值的项和""的项
3. 去掉异常值
"""
# 对每一类型的职位进行数据清洗：
def clean_data(df):
    # 去掉重复项
    df = df.drop_duplicates(subset=['url'])
    # 去掉含有空值和“”的项
    df = df.dropna()
    for att in attr:
        df = df[~df[att].isin([""])]
    # 去掉work_place值异常的项
    df = df[~df['work_place'].str.contains("{{item.city}}")]
    # 去掉异常值
    df = df[~df['salary_max'].isin([1])]
    return df

# 分职位对数据进行清洗
df_ai = clean_data(df_ai)
df_backend = clean_data(df_backend)
df_DBA = clean_data(df_DBA)
df_enterprise_software = clean_data(df_enterprise_software)
df_frontend = clean_data(df_frontend)
df_hardware_development = clean_data(df_hardware_development)
df_high_position = clean_data(df_high_position)
df_mobile_development = clean_data(df_mobile_development)
df_operation_maintenance = clean_data(df_operation_maintenance)
df_project_management = clean_data(df_project_management)
df_software_test = clean_data(df_software_test)

# 对所有数据进行清洗
print(len(df_all))
df_all = clean_data(df_all)
print(len(df_all))
# Out:
# 44916
# 25685

# %% [markdown]
# # 数据可视化：

# %%
import matplotlib.pyplot as plt
import collections
# 解决中文无法显示的问题
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

degree_dict = collections.Counter(df_all['degree'])
#for k,v in degree_dict.items():
#    print(k+":"+str(v))

# 学历要求分布饼状图
plt.figure(figsize=(15,9))
sizes = degree_dict.values() #每块值
labels = degree_dict.keys() #定义标签
colors = ['springgreen','yellowgreen','lightskyblue','yellow','peachpuff'] #每块颜色定义
patches,text1,text2 = plt.pie(sizes,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1.1,#图例距圆心半径倍距离
                      autopct = '%3.2f%%', #数值保留固定小数位
                      shadow = False, #无阴影设置
                      startangle =90, #逆时针起始角度设置
                      pctdistance = 0.6) #数值距圆心半径倍数距离

# 设置图中文字大小
for t in text1:
    t.set_size(20)
for t in text2:
    t.set_size(13)
plt.axis('equal')
# 设置图例标题文字大小
plt.rcParams.update({'font.size': 15})
plt.legend(title="学历要求分布饼状图",loc="center left", prop={'family':'SimHei','size':15})
plt.savefig("./image/300dpi/学历要求分布饼状图-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/学历要求分布饼状图-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/学历要求分布饼状图-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 工作经验要求分布图
experience_dict = collections.Counter(df_all['experience'])
experience_dict_ord = collections.OrderedDict()
experience_dict_ord['经验不限'] = experience_dict['经验不限']
experience_dict_ord['经验应届毕业生'] = experience_dict['经验应届毕业生']
experience_dict_ord['经验1年以下'] = experience_dict['经验1年以下']
experience_dict_ord['经验1-3年'] = experience_dict['经验1-3年']
experience_dict_ord['经验3-5年'] = experience_dict['经验3-5年']
experience_dict_ord['经验5-10年'] = experience_dict['经验5-10年']
experience_dict_ord['经验10年以上'] = experience_dict['经验10年以上']
#for k,v in experience_dict.items():
#    print(k+":"+str(v))
plt.figure(figsize=(15,9))
sizes = experience_dict_ord.values() #每块值
labels = experience_dict_ord.keys() #定义标签
colors = ['yellow','yellowgreen','lightskyblue','springgreen','cyan','peachpuff','seashell'] #每块颜色定义
patches,text1,text2 = plt.pie(sizes,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1.1,#图例距圆心半径倍距离
                      autopct = '%3.2f%%', #数值保留固定小数位
                      shadow = False, #无阴影设置
                      startangle =90, #逆时针起始角度设置
                      pctdistance = 0.6) #数值距圆心半径倍数距离
i = 0
for t in text1:
    pass

plt.axis('equal')
plt.legend(title="工作经验要求分布饼状图")
plt.savefig("./image/300dpi/工作经验要求分布饼状图-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/工作经验要求分布饼状图-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/工作经验要求分布饼状图-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 分地区岗位需求分布
work_place_dict = collections.Counter(df_all['work_place'])
work_place_dict= sorted(work_place_dict.items(), key=lambda d:d[1], reverse = True)
work_place_top20 = dict(work_place_dict[:20])
plt.figure(figsize=(15,9))
plt.bar(work_place_top20.keys(), work_place_top20.values())
plt.title('分地区岗位需求（TOP20）')
plt.xlabel('地区')
plt.ylabel('岗位数量(单位：个)')
plt.savefig("./image/300dpi/分地区岗位需求分布-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/分地区岗位需求分布-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/分地区岗位需求分布-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 不同职位需求
position_dict = collections.Counter(df_all['position'])

position_dict= sorted(position_dict.items(), key=lambda d:d[1], reverse = True)
position_top20 = dict(position_dict[:20])
#position_top20

plt.figure(figsize=(15,9))
plt.bar(position_top20.keys(), position_top20.values())
plt.title('不同职位需求（TOP20）')
plt.xlabel('职位名称')
plt.xticks(rotation=45)
plt.ylabel('职位数量(单位：个)')
plt.savefig("./image/300dpi/不同职位需求柱状图-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/不同职位需求柱状图-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/不同职位需求柱状图-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 公司分析
company_name_dict = collections.Counter(df_all['company_name'])
company_name_dict= sorted(company_name_dict.items(), key=lambda d:d[1], reverse = True)
company_name_top20 = dict(company_name_dict[:20])
#company_name_top20

plt.figure(figsize=(15,9))
plt.bar(company_name_top20.keys(), company_name_top20.values())
plt.title('公司岗位数量（TOP20）')
plt.xlabel('公司名')
plt.xticks(rotation=90)
plt.ylabel('职位数量(单位：个)')
plt.savefig("./image/300dpi/公司岗位数量TOP20柱状图-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/公司岗位数量TOP20柱状图-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/公司岗位数量TOP20柱状图-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 公司融资情况分析
company_finance_dict = collections.Counter(df_all['company_finance'])

# 学历要求分布饼状图
plt.figure(figsize=(20,9))
sizes = company_finance_dict.values() #每块值
labels = company_finance_dict.keys() #定义标签
colors = ['springgreen','yellowgreen','lightskyblue','yellow','peachpuff','seashell','cyan','lightgrey'] #每块颜色定义
patches,text1,text2 = plt.pie(sizes,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1.1,#图例距圆心半径倍距离
                      autopct = '%3.2f%%', #数值保留固定小数位
                      shadow = False, #无阴影设置
                      startangle =90, #逆时针起始角度设置
                      pctdistance = 0.6) #数值距圆心半径倍数距离

# 设置图中文字大小
"""
for t in text1:
    t.set_size(20)
for t in text2:
    t.set_size(13)
"""
plt.axis('equal')
# 设置图例标题文字大小
plt.rcParams.update({'font.size': 15})
plt.legend(title="公司融资情况分析饼状图",loc=1, prop={'family':'SimHei','size':15})
plt.savefig("./image/300dpi/公司融资情况分析-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/公司融资情况分析-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/公司融资情况分析-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 公司规模统计
import collections
company_scale_dict = collections.Counter(df_all['company_scale'])

company_scale_order_dict = collections.OrderedDict()
company_scale_order_dict['少于15人'] = company_scale_dict['少于15人']
company_scale_order_dict['15-50人'] = company_scale_dict['15-50人'] + company_scale_dict['10-50人']
company_scale_order_dict['50-150人'] = company_scale_dict['50-150人']
company_scale_order_dict['150-500人'] = company_scale_dict['150-500人']
company_scale_order_dict['500-2000人'] = company_scale_dict['500-2000人']
company_scale_order_dict['2000人以上'] = company_scale_dict['2000人以上']
company_scale_order_dict['少于15人'] = company_scale_dict['少于15人']

plt.figure(figsize=(15,9))
sizes = company_scale_order_dict.values() #每块值
labels = company_scale_order_dict.keys() #定义标签
colors = ['springgreen','lightgrey','lightskyblue','yellow','peachpuff','cyan'] #每块颜色定义
patches,text1,text2 = plt.pie(sizes,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1.1,#图例距圆心半径倍距离
                      autopct = '%3.2f%%', #数值保留固定小数位
                      shadow = False, #无阴影设置
                      startangle =90, #逆时针起始角度设置
                      pctdistance = 0.6) #数值距圆心半径倍数距离

# 设置图中文字大小
"""
for t in text1:
    t.set_size(20)
for t in text2:
    t.set_size(13)
"""
plt.axis('equal')
# 设置图例标题文字大小
plt.rcParams.update({'font.size': 15})
plt.legend(title="公司规模统计",loc=1, prop={'family':'SimHei','size':15})

#保存图片
plt.savefig("./image/300dpi/公司规模统计饼状图-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/公司规模统计饼状图-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/公司规模统计饼状图-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()

# %%
# 职位数据可视化（实习/ 正式岗位）
# 去掉实习生岗位
df_intership = df_all[df_all['position'].str.contains("实习")]
df_non_intership = df_all[~df_all['position'].str.contains("实习")]
print(df_intership)
num_intership = len(df_intership)
num_non_intership = len(df_non_intership)
data={}
data['实习'] = len(num_intership)
data['非实习'] = len(num_non_intership)

sizes = data.keys()
labels = data.values()
colors = ['springgreen','lightgrey']
patches,text1,text2 = plt.pie(sizes,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1.1,#图例距圆心半径倍距离
                      autopct = '%3.2f%%', #数值保留固定小数位
                      shadow = False, #无阴影设置
                      startangle =90, #逆时针起始角度设置
                      pctdistance = 0.6) #数值距圆心半径倍数距离

plt.axis('equal')
# 设置图例标题文字大小
plt.rcParams.update({'font.size': 15})
plt.legend(title="整体数据分布",loc=1, prop={'family':'SimHei','size':15})

#保存图片
plt.savefig("./image/300dpi/整体数据分布饼状图-300dpi.jpg",dpi=300,bbox_inches = 'tight')
plt.savefig("./image/200dpi/整体数据分布饼状图-200dpi.jpg",dpi=200,bbox_inches = 'tight')
plt.savefig("./image/100dpi/整体数据分布饼状图-100dpi.jpg",dpi=100,bbox_inches = 'tight')
plt.show()
# Out:
#                        position  salary_min  salary_max experience degree  \
# 44                机器学习-2020届实习生           4         5.0    经验应届毕业生     本科
# 113              计算机视觉-2020届实习生           4         5.0    经验应届毕业生     本科
# 186                 机器学习实习生-音视频           8        10.0       经验不限     硕士
# 195                 机器学习实习生-音视频           8        10.0       经验不限     硕士
# 209           AI Lab实习生 - 计算机视觉           6        10.0       经验不限     本科
# 223             计算机视觉工程师（全职／实习）          20        40.0       经验不限     本科
# 256                   视觉设计（实习生）           3         4.0    经验应届毕业生     本科
# 417   【暑期实习生】算法工程师-机器学习(J10238)           4         6.0    经验应届毕业生     本科
# 420                  深度/机器学习实习生          10        20.0       经验不限     硕士
# 437                机器学习（实习生／校招）           3         6.0    经验应届毕业生     本科
# 460                机器学习/深度学习实习生           2         4.0    经验应届毕业生     本科
# 485                   机器学习研发实习生           3         5.0       经验不限     不限
# 489                机器学习工程师（实习生）          10        20.0       经验不限     硕士
# 561                      机器学习实习           3         6.0    经验应届毕业生     本科
# 565                   机器学习算法实习生           4         6.0       经验不限     本科
# 570              机器学习算法实习生(可转正）           5         8.0    经验应届毕业生     本科
# 576                 机器学习平台开发实习生           2         4.0    经验应届毕业生     本科
# 579                     机器学习实习生           3         4.0    经验应届毕业生     硕士
# 580   {实习生} 自然语言处理与机器学习-算法和研究方向           4         7.0       经验不限     硕士
# 583          机器学习平台开发实习生(DGNet)           4         5.0     经验1年以下     本科
# 589                     机器学习实习生           4         6.0    经验应届毕业生     硕士
# 598            机器学习算法实习生-AI Lab           2         4.0       经验不限     本科
# 619                     机器学习实习生           4         8.0    经验应届毕业生     硕士
# 620       2020届 - 算法实习生--机器学习方向           3         5.0    经验应届毕业生     硕士
# 626                     机器学习实习生           4         7.0       经验不限     硕士
# 636                   机器学习开发实习生           3         4.0    经验应届毕业生     本科
# 638         人工智能与机器学习实习生岗（金融方向）           4         6.0    经验应届毕业生     本科
# 654                   机器学习算法实习生           3         4.0    经验应届毕业生     本科
# 655        机器学习算法实习生 (MJ000210)           3         6.0    经验应届毕业生     不限
# 658         AML机器学习平台开发实习生（可转正）           3         6.0       经验不限     本科
# ...                         ...         ...         ...        ...    ...
# 2449                    测试开发实习生           4         7.0       经验不限     本科
# 2464                    测试开发实习生           3         6.0       经验不限     本科
# 2479                    测试开发实习生           8        15.0       经验不限     本科
# 2489                    测试开发实习生           4         6.0       经验不限     本科
# 2492                    测试开发实习生           4         6.0       经验不限     本科
# 2494       测试开发实习生-抖音大数据方向（可转正）           2         4.0    经验应届毕业生     本科
# 2496     【暑期实习生】测试开发实习生(J10354)           2         4.0    经验应届毕业生     本科
# 2509                    测试开发实习生           6         9.0    经验应届毕业生     本科
# 2524                    测试开发实习生           2         4.0     经验1年以下     本科
# 2539        测试开发实习生（可转正）-核心广告系统           4         8.0       经验不限     本科
# 2618   性能测试工程师（实习/PaaS）(J12522)           3         5.0    经验应届毕业生     本科
# 2690  【暑期实习生】软件/硬件测试工程师(J10169)           3         6.0    经验应届毕业生     本科
# 2709                       测试实习           1         2.0     经验1年以下     本科
# 2742                    硬件测试实习生           3         4.0    经验应届毕业生     本科
# 2761                    硬件测试实习生           3         4.0    经验应届毕业生     本科
# 2803                    软件测试实习生           2         4.0       经验不限     大专
# 2872                      硬件实习生           3         4.0    经验应届毕业生     本科
# 3041                  游戏测试员(实习)           3         4.0    经验应届毕业生     不限
# 3043                  游戏测试（实习生）           4         6.0    经验应届毕业生     本科
# 3046                    游戏测试实习生           3         5.0    经验应届毕业生     本科
# 3110                    游戏测试实习生           2         4.0    经验应届毕业生     不限
# 3120                   游戏测试（实习）           2         3.0    经验应届毕业生     本科
# 3127                    游戏测试实习生           4         6.0       经验不限     大专
# 3172                    游戏测试实习生           2         4.0    经验应届毕业生     本科
# 3174                    游戏测试实习生           4         6.0       经验不限     大专
# 3175                    游戏测试实习生           4         7.0       经验不限     大专
# 3180                    游戏测试实习生           4         6.0       经验不限     大专
# 3218                    游戏策划实习生           2         3.0    经验应届毕业生     大专
# 3221                     游戏策划实习           3         4.0       经验不限     不限
# 3238                      客服实习生           1         2.0       经验不限     不限
#
#      work_place    company_name company_type company_finance company_scale  \
# 44           北京         阿里巴巴-高德           工具            上市公司       2000人以上
# 113          北京         阿里巴巴-高德           工具            上市公司       2000人以上
# 186          北京            字节跳动        文娱丨内容              C轮       2000人以上
# 195          深圳            字节跳动        文娱丨内容              C轮       2000人以上
# 209          上海            字节跳动        文娱丨内容              C轮       2000人以上
# 223          杭州           ULSee  移动互联网,文娱丨内容              A轮       50-150人
# 256          杭州             铭师堂           教育           不需要融资     500-2000人
# 417          上海            哈啰出行     移动互联网,硬件           D轮及以上       2000人以上
# 420          杭州            深睿医疗  移动互联网,医疗丨健康              B轮      150-500人
# 437          北京              数美    企业服务,数据服务              B轮      150-500人
# 460          武汉              极验    信息安全,数据服务              B轮       50-150人
# 485          深圳              腾讯           社交            上市公司       2000人以上
# 489          北京        北京大数据研究院        教育,其他           不需要融资     500-2000人
# 561          重庆            白狮创新    数据服务,信息安全             天使轮        15-50人
# 565          北京              陌陌           社交            上市公司     500-2000人
# 570          上海            字节跳动        文娱丨内容              C轮       2000人以上
# 576          北京        Mobvista         广告营销            上市公司     500-2000人
# 579          北京            晶泰科技         企业服务              B轮       50-150人
# 580          北京           三角兽科技        移动互联网              B轮      150-500人
# 583          北京            格灵深瞳    企业服务,数据服务              C轮      150-500人
# 589          北京      Gridsum 国双    数据服务,企业服务            上市公司     500-2000人
# 598          北京            字节跳动        文娱丨内容              C轮       2000人以上
# 619          上海  竹间智能科技(上海)有限公司     移动互联网,其他              B轮      150-500人
# 620          北京            阿里健康     移动互联网,电商            上市公司     500-2000人
# 626          北京            阿姨多多   移动互联网,消费生活           不需要融资         少于15人
# 636          北京            智铀科技         数据服务              A轮       50-150人
# 638          上海            蝶威智能           金融           不需要融资         少于15人
# 654          北京            智铀科技         数据服务              A轮       50-150人
# 655          上海            星环科技         数据服务              C轮      150-500人
# 658          北京            字节跳动        文娱丨内容              C轮       2000人以上
# ...         ...             ...          ...             ...           ...
# 2449         北京            字节跳动        文娱丨内容              C轮       2000人以上
# 2464         北京            字节跳动        文娱丨内容              C轮       2000人以上
# 2479         北京            字节跳动        文娱丨内容              C轮       2000人以上
# 2489         北京            Keep     社交,文娱丨内容           D轮及以上     500-2000人
# 2492         北京             牛投邦     金融,移动互联网              B轮      150-500人
# 2494         上海            字节跳动        文娱丨内容              C轮       2000人以上
# 2496         上海            哈啰出行     移动互联网,硬件           D轮及以上       2000人以上
# 2509         上海            字节跳动        文娱丨内容              C轮       2000人以上
# 2524         北京            字节跳动        文娱丨内容              C轮       2000人以上
# 2539         北京            字节跳动        文娱丨内容              C轮       2000人以上
# 2618         成都           北森云计算         企业服务            上市公司     500-2000人
# 2690         上海            哈啰出行     移动互联网,硬件           D轮及以上       2000人以上
# 2709         成都    成都博智云创科技有限公司    数据服务,企业服务           不需要融资       50-150人
# 2742         深圳   Makeblock童心制物           教育              C轮     500-2000人
columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-cbfc01a19d37> in <module>
#       7 num_non_intership = len(df_non_intership)
#       8 data={}
# ----> 9 data['实习'] = len(num_intership)
#      10 data['非实习'] = len(num_non_intership)
#      11
#
# TypeError: object of type 'int' has no len()

# %%
# 按岗位类型统计最高工资和最低工资
# 下面两个数据结构为：{岗位名：最低（高）工资}
salary_min = {}
salary_max = {}

def salary_by_position(table_name,key_name):
    sql = "select * from "+table_name
    df = pd.read_sql(sql,conn)
    df = clean_data(df)
    salary_min[key_name] = df['salary_min'].min()
    salary_max[key_name] = df['salary_max'].max()

for k,v in position_dict.items():
    salary_by_position(k,v)

print("按职位工资（最高）：")
for s,v in salary_max.items():
    print(s+":"+str(v))
  
print("\n按职位工资（最低）：")
for s,v in salary_min.items():
    print(s+":"+str(v))
# Out:
# 按职位工资（最高）：
# 人工智能:140.0
# 后端开发:200
# 数据库管理员:100
# 企业软件开发:70
# 前端:200
# 硬件开发:125
# 高端职位:200
# 移动开发:120
# 运维:300
# 项目管理:100
# 软件测试:60
#
# 按职位工资（最低）：
# 人工智能:1
# 后端开发:1
# 数据库管理员:1
# 企业软件开发:2
# 前端:1
# 硬件开发:1
# 高端职位:1
# 移动开发:1
# 运维:1
# 项目管理:1
# 软件测试:1

# %%
# 按岗位类型统计最低平均工资和最高平均工资
# 下面两个数据结构为：{岗位名：最低（高）平均工资}
salary_min_avg = {}
salary_max_avg = {}

# 读取岗位平均最低（高）工资数据到上面的数据结构中
def salary_avg_by_position(table_name,key_name):
    sql = "select * from "+table_name
    df = pd.read_sql(sql,conn)
    df = clean_data(df)
    salary_min_avg[key_name] = df['salary_min'].mean()
    salary_max_avg[key_name] = df['salary_max'].mean()


for k,v in position_dict.items():
    salary_avg_by_position(k,v)

print("按职位平均工资（最高）：")
for s,v in salary_max_avg.items():
    print(s+":"+str(v))
  
print("\n按职位平均工资（最低）：")
for s,v in salary_min_avg.items():
    print(s+":"+str(v))
# Out:
# 按职位平均工资（最高）：
# 人工智能:34.733852364475204
# 后端开发:26.668284789644012
# 数据库管理员:28.452560240963855
# 企业软件开发:16.731308411214954
# 前端:21.785619761799737
# 硬件开发:21.71715145436309
# 高端职位:37.455812480202724
# 移动开发:22.849740932642487
# 运维:23.075414364640885
# 项目管理:16.00334448160535
# 软件测试:20.032712915961646
#
# 按职位平均工资（最低）：
# 人工智能:19.245391705069125
# 后端开发:15.276551927037364
# 数据库管理员:16.46272590361446
# 企业软件开发:9.80981308411215
# 前端:12.796206440229378
# 硬件开发:12.626629889669006
# 高端职位:22.493506493506494
# 移动开发:13.376511226252159
# 运维:13.448618784530387
# 项目管理:9.594202898550725
# 软件测试:11.852509870276368

# %%
"""
按职位进行最低工资分析
"""
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np

group_data = list(salary_min_analysis.values())
group_names = list(salary_min_analysis.keys())
group_mean = np.mean(group_data)

plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
ax.barh(group_names, group_data)

ax.axvline(group_mean, ls='--', color='r')
ax.set(xlim=[0,25], xlabel='薪资（单位：K）', ylabel='职位类型',title='最低平均工资分析')
plt.show()

# %%
"""
按职位进行最高工资分析
"""
group_data = list(salary_max_analysis.values())
group_names = list(salary_max_analysis.keys())
group_mean = np.mean(group_data)

plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
ax.barh(group_names, group_data)

ax.axvline(group_mean, ls='--', color='r')
ax.set(xlim=[0,40], xlabel='薪资（单位：K）', ylabel='职位类型',title='最高平均工资分析')
plt.show()
